# %%
import pandas as pd
import numpy as np
from datetime import date

# import datasets
apps_df = pd.read_csv('transfermarkt-data/appearances.csv')
games_df = pd.read_csv('transfermarkt-data/club_games.csv')
clubs_df = pd.read_csv('transfermarkt-data/clubs.csv')
comps_df = pd.read_csv('transfermarkt-data/competitions.csv')
events_df = pd.read_csv('transfermarkt-data/game_events.csv')
values_df = pd.read_csv('transfermarkt-data/player_valuations.csv')
players_df = pd.read_csv('transfermarkt-data/players.csv')

# %%
# GLOBAL VARIABLES to restrict analysis to
LEAGUES = ['premier-league', 'laliga', 'ligue-1', 'serie-a', 'bundesliga']

#######################
# dataset of players

league_ids = []
for league in LEAGUES:
    league_id = comps_df.loc[comps_df['competition_code'] == league, 'competition_id'].values[0]
    league_ids.append(league_id)

playerpool_df = players_df[players_df['current_club_domestic_competition_id'].isin(league_ids)]

print(playerpool_df)

# lifespan_df = values_df[['player_id', 'date', 'market_value_in_eur']]
    
#print(lifespan_df[lifespan_df['player_id'] == 581678])
# print(players_df[players_df['name']=='Jude Bellingham'])

# print(values_df.columns)
# Out:
#        player_id first_name   last_name                name  last_season  \
# 1           1428       Mike       Hanke          Mike Hanke         2013
# 3           1587      Mario    Eggimann      Mario Eggimann         2012
# 5           2306     Markus      Miller       Markus Miller         2014
# 7           2805  Christian      Pander    Christian Pander         2014
# 8           2878     Yassin      Mikari       Yassin Mikari         2012
# ...          ...        ...         ...                 ...          ...
# 28444     581678       Jude  Bellingham     Jude Bellingham         2022
# 28446     659513   Soumaïla   Coulibaly  Soumaïla Coulibaly         2022
# 28449     877620     Moussa        Mané         Moussa Mané         2021
# 28453     111527    Mathieu     Duhamel     Mathieu Duhamel         2014
# 28454     164928       Ilan     Boccara        Ilan Boccara         2013
#
#        current_club_id         player_code country_of_birth  \
# 1                   60          mike-hanke          Germany
# 3                   42      mario-eggimann      Switzerland
# 5                   42       markus-miller          Germany
# 7                   42    christian-pander          Germany
# 8                  750       yassin-mikari      Switzerland
# ...                ...                 ...              ...
# 28444               16     jude-bellingham          England
# 28446               16  soumaila-coulibaly           France
# 28449             6195         moussa-mane          Senegal
# 28453            14171     mathieu-duhamel           France
# 28454            14171        ilan-boccara           France
#
#               city_of_birth country_of_citizenship  ...   foot height_in_cm  \
# 1                      Hamm                Germany  ...  right        185.0
# 3                     Brugg            Switzerland  ...  right        190.0
# 5      Lindenberg im Allgäu                Germany  ...  right        189.0
# 7                   Münster                Germany  ...    NaN          NaN
# 8                    Zürich                Tunisia  ...   left        172.0
# ...                     ...                    ...  ...    ...          ...
# 28444           Stourbridge                England  ...  right        186.0
# 28446           Montfermeil                 France  ...   left        191.0
# 28449            Ziguinchor                  Italy  ...  right        182.0
# 28453     Mont-Saint-Aignan                 France  ...  right        183.0
# 28454  Boulogne-Billancourt                 Israel  ...  right        178.0
#
#       market_value_in_eur highest_market_value_in_eur  \
# 1                     NaN                   5000000.0
# 3                     NaN                   3000000.0
# 5                     NaN                   3500000.0
# 7                     NaN                   6500000.0
# 8                     NaN                   2800000.0
# ...                   ...                         ...
# 28444         120000000.0                 120000000.0
# 28446           1000000.0                   1000000.0
# 28449             50000.0                     50000.0
# 28453                 NaN                   2000000.0
# 28454                 NaN                    500000.0
#
#        contract_expiration_date          agent_name  \
# 1                           NaN                 NaN
# 3                           NaN                 NaN
# 5                           NaN  ARP Sportmarketing
# 7                           NaN                 NaN
# 8                           NaN            Rhein AG
# ...                         ...                 ...
# 28444       2025-06-30 00:00:00                 NaN
# 28446       2026-06-30 00:00:00         Epic Sports
# 28449       2023-06-30 00:00:00                 BDN
# 28453                       NaN                 NaN
# 28454                       NaN                 NaN
#
#                                                image_url  \
# 1      https://img.a.transfermarkt.technology/portrai...
# 3      https://img.a.transfermarkt.technology/portrai...
# 5      https://img.a.transfermarkt.technology/portrai...
# 7      https://img.a.transfermarkt.technology/portrai...
# 8      https://img.a.transfermarkt.technology/portrai...
# ...                                                  ...
# 28444  https://img.a.transfermarkt.technology/portrai...
# 28446  https://img.a.transfermarkt.technology/portrai...
# 28449  https://img.a.transfermarkt.technology/portrai...
# 28453  https://img.a.transfermarkt.technology/portrai...
# 28454  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url  \
# 1      https://www.transfermarkt.co.uk/mike-hanke/pro...
# 3      https://www.transfermarkt.co.uk/mario-eggimann...
# 5      https://www.transfermarkt.co.uk/markus-miller/...
# 7      https://www.transfermarkt.co.uk/christian-pand...
# 8      https://www.transfermarkt.co.uk/yassin-mikari/...
# ...                                                  ...
# 28444  https://www.transfermarkt.co.uk/jude-bellingha...
# 28446  https://www.transfermarkt.co.uk/soumaila-couli...
# 28449  https://www.transfermarkt.co.uk/moussa-mane/pr...
# 28453  https://www.transfermarkt.co.uk/mathieu-duhame...
# 28454  https://www.transfermarkt.co.uk/ilan-boccara/p...
#
#       current_club_domestic_competition_id             current_club_name
# 1                                       L1                   SC Freiburg
# 3                                       L1                   Hannover 96
# 5                                       L1                   Hannover 96
# 7                                       L1                   Hannover 96
# 8                                      FR1        FC Sochaux-Montbéliard
# ...                                    ...                           ...
# 28444                                   L1             Borussia Dortmund
# 28446                                   L1             Borussia Dortmund
# 28449                                  IT1                    SSC Napoli
# 28453                                  FR1  Thonon Évian Grand Genève FC
# 28454                                  FR1  Thonon Évian Grand Genève FC
#
# [10400 rows x 23 columns]
